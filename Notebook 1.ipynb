# %%
# !pip install opencv-python==4.7.0.68
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.8/61.8 MB 28.5 MB/s eta 0:00:00
# ...
# WARNING: You are using pip version 22.0.4; however, version 23.0 is available.
# You should consider upgrading via the '/root/venv/bin/python -m pip install --upgrade pip' command.

# %%
# !apt update && apt install -y python3-opencv
# !pip install opencv-python
# Out:
# Selecting previously unselected package libdconf1:amd64.
# Preparing to unpack .../018-libdconf1_0.30.1-2_amd64.deb ...
# Unpacking libdconf1:amd64 (0.30.1-2) ...
# Selecting previously unselected package dconf-service.
# Preparing to unpack .../019-dconf-service_0.30.1-2_amd64.deb ...
# Unpacking dconf-service (0.30.1-2) ...
# 7Progress: [  8%] [####......................................................] 8Selecting previously unselected package dconf-gsettings-backend:amd64.
# Preparing to unpack .../020-dconf-gsettings-backend_0.30.1-2_amd64.deb ...
# Unpacking dconf-gsettings-backend:amd64 (0.30.1-2) ...
# Selecting previously unselected package gdal-data.
# Preparing to unpack .../021-gdal-data_2.4.0+dfsg-1+deb10u1_all.deb ...
# Unpacking gdal-data (2.4.0+dfsg-1+deb10u1) ...
# Selecting previously unselected package libgfortran5:amd64.
# Preparing to unpack .../022-libgfortran5_8.3.0-6_amd64.deb ...
# Unpacking libgfortran5:amd64 (8.3.0-6) ...
# ...

# %%
import cv2

# %%
dirs = [d for d in os.listdir() if os.path.isdir(d)]
print(dirs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [4], line 1
# ----> 1 dirs = [d for d in os.listdir() if os.path.isdir(d)]
#       2 print(dirs)
#
# NameError: name 'os' is not defined

# %%
import os

# Directory containing the images

img_dir = os.path.join(os.getcwd(),'images')
os.mkdir(img_dir)
image_path = os.path.join(img_dir, 'pavan8.jpg')


# Set the desired dimensions 
for the resized images
width = 150
height = 150
dim = (width, height)

# Loop through each image in the directory
for filename in os.listdir(img_dir):
    if filename.endswith(".jpg"):
        # Load the image
        img = cv2.imread(os.path.join(img_dir, filename))

        # Resize the image
        resized = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)

        # Save the resized image
        cv2.imwrite(os.path.join(img_dir, "resized_" + filename), resized)

# %%
import os
import cv2

# Directory containing the images

img_dir = os.path.join(os.getcwd(),'images')
os.mkdir(img_dir)
image_path = os.path.join(img_dir, 'pavan8.jpg')

# Loop through each image in the directory
for filename in os.listdir(img_dir):
    if filename.endswith(".jpg"):
        # Load the image
        img = cv2.imread(os.path.join(img_dir, filename))

        # Convert the image to grayscale
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

        # Save the grayscale image
        cv2.imwrite(os.path.join(img_dir, "gray_" + filename), gray)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In [9], line 7
#       4 # Directory containing the images
#       6 img_dir = os.path.join(os.getcwd(),'images')
# ----> 7 os.mkdir(img_dir)
#       8 image_path = os.path.join(img_dir, 'pavan8.jpg')
#      10 # Loop through each image in the directory
#
# FileExistsError: [Errno 17] File exists: '/work/images'

# %%
# importing libraries.
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
 
 
# storing image path
fname = r'pavan8.jpg'
 
# opening image using pil
image = Image.open(fname).convert("L")
 
# mapping image to gray scale
plt.imshow(image, cmap='gray')
plt.show()

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=3676698f-504b-4e45-95f4-cd3dd0ba07c5' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
